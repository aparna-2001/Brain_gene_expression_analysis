# %% [markdown]
# <a href="https://colab.research.google.com/github/aparna-2001/Brain_gene_expression_analysis/blob/main/Brain_gene_expression_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install GEOparse
import GEOparse

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import zipfile

# %%
with open ('/content/GSE25219-GPL5175_series_matrix.txt', 'r') as file:
  data = pd.read_csv(file, sep='\t')

print(data)

data_table = pd.DataFrame(data)
data_table.head(5)
# Out:
# /tmp/ipython-input-1782945974.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file, sep='\t')
# ...

# %%
#downloading and parse the dataset

gse = GEOparse.get_GEO(geo="GSE25219", destdir='./')

#accesing the expression data

gpl = gse.gpls["GPL5175"]
expression_data = gse.pivot_samples('VALUE')

print(expression_data.head())
# Out:
# Streaming output truncated to the last 5000 lines.
# 26-Jan-2026 13:38:20 DEBUG GEOparse - SAMPLE: GSM704094
# DEBUG:GEOparse:SAMPLE: GSM704094
# 26-Jan-2026 13:38:20 DEBUG GEOparse - SAMPLE: GSM704095
# DEBUG:GEOparse:SAMPLE: GSM704095
# 26-Jan-2026 13:38:20 DEBUG GEOparse - SAMPLE: GSM704096
# DEBUG:GEOparse:SAMPLE: GSM704096
# 26-Jan-2026 13:38:20 DEBUG GEOparse - SAMPLE: GSM704097
# DEBUG:GEOparse:SAMPLE: GSM704097
# 26-Jan-2026 13:38:20 DEBUG GEOparse - SAMPLE: GSM704098
# DEBUG:GEOparse:SAMPLE: GSM704098
# 26-Jan-2026 13:38:20 DEBUG GEOparse - SAMPLE: GSM704099
# DEBUG:GEOparse:SAMPLE: GSM704099
# 26-Jan-2026 13:38:20 DEBUG GEOparse - SAMPLE: GSM704100
# DEBUG:GEOparse:SAMPLE: GSM704100
# 26-Jan-2026 13:38:20 DEBUG GEOparse - SAMPLE: GSM704101
# DEBUG:GEOparse:SAMPLE: GSM704101
# 26-Jan-2026 13:38:20 DEBUG GEOparse - SAMPLE: GSM704102
# DEBUG:GEOparse:SAMPLE: GSM704102
# 26-Jan-2026 13:38:20 DEBUG GEOparse - SAMPLE: GSM704103
# DEBUG:GEOparse:SAMPLE: GSM704103
# ...

# %%
url = "https://ftp.ncbi.nlm.nih.gov/geo/series/GSE25nnn/GSE25219/matrix/GSE25219-GPL5175_series_matrix.txt.gz"

data = pd.read_csv(url, sep='\t', compression = 'gzip',
                   skiprows = lambda x: not(x>50 and not str(x).startswith('!'))
                  ,index_col = 0, comment ='!'
                   )

print(data.shape)
print(data.head)
# Out:
# (17565, 1340)
# <bound method NDFrame.head of          GSM703914  GSM703915  GSM703916  GSM703917  GSM703918  GSM703919  \
# ID_REF
# 2315554    6.51949    6.19527    5.82233    6.15533    6.11070    6.31911
# 2315633    7.28289    7.68305    6.64229    7.55538    7.15634    7.73684
# 2315674    5.78650    5.44462    5.50665    5.83645    5.42284    5.75245
# 2315739    6.08580    6.18029    5.56690    6.10089    6.25135    6.16108
# 2315894    6.25325    6.04638    6.33970    6.41998    5.61124    5.93543
# ...            ...        ...        ...        ...        ...        ...
# 7385552    6.71209    6.55121    6.48373    6.51370    6.32918    6.66434
# 7385611    7.06399    7.43812    7.65839    8.14528    7.27035    6.41940
# 7385641    7.56522    7.97814    8.44036    8.60247   10.65350    8.41393
# 7385683    7.98985    8.52158    7.87273    8.66420    8.27011    8.62463
# 7385696    6.96168    7.31775    6.95217    7.25746    7.27047    7.66876
#
# ...

# %%
with open('/content/GSE25219-GPL5175_series_matrix.txt', 'r') as file:
  lines = file.readlines()

metadata = [line.strip() for line in lines if line.startswith('!')]
print(metadata)
# Out:
# ['!series_matrix_table_end']

# %%
with open('/content/GSE25219-GPL5175_series_matrix.txt', 'r') as file:
  lines = file.readlines()

data = [line.strip() for line in lines if not line.startswith('!')]
#print(data[10])

data = '\n'.join(data)
print(data.head())
